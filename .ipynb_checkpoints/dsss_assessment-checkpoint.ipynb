# %% [markdown]
# ***
# #### About this notebook
# This is an assignment for Data Science for Spatial Systems (CASA0006)
#
# ##### Student Name: PHILYOUNG JEONG
# ##### Student Number: 21047736
# ##### Code & Data are available [here](https://github.com/phily5051/CASA0006.git)
# ##### Word Count (excluding Table captions): 1999 words
# ***

# %% [markdown]
# # What are the crucial factors for business air traveler's satisfaction?

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# Air travel has become an integral part of modern life, providing a fast and convenient way to travel across the world for various travel purposes. Especially, business travel, such as meetings and conferences, is heavily dependent on the availability of air travel, and more businesses turn to air travel.
#
# This paper presents the results of an exploratory analysis that uses open data to develop four machine learning models aimed at identifying the important features that influence business air travelers' satisfaction and predicting their satisfaction accurately.

# %% [markdown]
# ### 1.1. Packages
# The below are essential for the implementation of the codes.

# %%
# count running time
import time
start_time = time.time()

# %%
import warnings 
warnings.filterwarnings('ignore')

# basic libraries
import numpy as np
import pandas as pd
import time

#visulaization modules
import missingno as msno
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# pipeline
from sklearn.pipeline import Pipeline

# metrics
import sklearn
from sklearn.model_selection import train_test_split, GridSearchCV, validation_curve, cross_val_score
from sklearn.metrics import (accuracy_score, 
                             precision_score,
                             recall_score,
                             f1_score, 
                             confusion_matrix,
                             mean_squared_error, 
                             r2_score)

from sklearn.feature_selection import SelectKBest, chi2

# preprocessors
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# model algorithams
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier


pd.set_option('display.max_rows', 300) # specifies number of rows to show
pd.options.display.float_format = '{:40,.4f}'.format # specifies default number format to 4 decimal places
plt.style.use('ggplot') # specifies that graphs should use ggplot styling
# %matplotlib inline

# Notebook settings
random_state = 42 # for reproducability
np.random.seed(random_state) # setting numpy random seed, as that is used for sklearn operations

# %% [markdown]
# ## 2. Literature Review and Research Question

# %% [markdown]
# **Literature**<br>
# Passenger satisfaction during air travel is influenced by several factors. Specifically, Noviantoro and Huang (2022) identified in-flight entertainment, booking convenience, and baggage service as crucial elements of passenger satisfaction. Ensuring quality services can improve airline's image and passenger satisfaction (Suki, 2014), and this can appeal to high-income passengers who fly frequently (Archana and Subha, 2012). Additionally, the International Civil Aviation Organization (2019) highlights that compared to leisure visitors, business travelers generate a greater economic impact on various sectors, including airlines, retail, and local industries, due to their higher expenditure on shop.
#
# These findings highlight the importance of providing high-quality services and the potential benefits that can be gained from business travelers. However, it is clear that the distinctive elements that contribute to business travelers' satisfaction have not yet studied in preceeding literature.
#
# **Research Question**<br>
# Therefore, this leads to the following question:
#
#       RQ: What are the crucial factors that contribute to business air traveler's satisfaction?
#
# This paper aims to identify important features contributing to business traveler's satisfaction. The effective strategies that enhance business air travelers' satisfaction is not only essential for airlines to improve their services and revenue, but it can also have positive impacts on the overall economic growth of the relevant industries.
# <br>

# %% [markdown]
# ## 3. Presentation of data
# The [Dataset](https://www.kaggle.com/datasets/binaryjoker/airline-passenger-satisfaction) was retrieved from Kaggle and it was based on an airline survey which did not contain any personal information. Passengers evaluated various factors, such as comfort, delay and service, and gave an overall feedback whether they were satisfied or not.

# %%
# read in data
data = pd.read_csv("https://raw.githubusercontent.com/phily5051/CASA0006/main/airline_passenger_satisfaction.csv")

# %%
# first five rows
data.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay                            Arrival Delay  \
# 0                2                                   5.0000
# 1               26                                  39.0000
# 2                0                                   0.0000
# 3                0                                   0.0000
# 4                0                                   1.0000
#
#    Departure and Arrival Time Convenience  ...  On-board Service  \
# 0                                       3  ...                 3
# 1                                       2  ...                 5
# 2                                       4  ...                 3
# 3                                       2  ...                 5
# 4                                       3  ...                 3
#
#    Seat Comfort  Leg Room Service  Cleanliness  Food and Drink  \
# 0             5                 2            5               5
# 1             4                 5            5               3
# 2             5                 3            5               5
# 3             5                 5            4               4
# 4             4                 4            5               4
#
#    In-flight Service  In-flight Wifi Service  In-flight Entertainment  \
# 0                  5                       3                        5
# 1                  5                       2                        5
# 2                  3                       4                        3
# 3                  5                       2                        5
# 4                  3                       3                        3
#
#    Baggage Handling             Satisfaction
# 0                 5  Neutral or Dissatisfied
# 1                 5                Satisfied
# 2                 3                Satisfied
# 3                 5                Satisfied
# 4                 3                Satisfied
#
# [5 rows x 24 columns]

# %%
# last five rows
data.tail()
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  \
# 129875              447                2
# 129876              308                0
# 129877              337                6
# 129878              337               31
# 129879              337                0
#
#                                   Arrival Delay  \
# 129875                                   3.0000
# 129876                                   0.0000
# 129877                                  14.0000
# 129878                                  22.0000
# 129879                                   0.0000
#
#         Departure and Arrival Time Convenience  ...  On-board Service  \
# 129875                                       4  ...                 5
# 129876                                       5  ...                 5
# 129877                                       5  ...                 3
# 129878                                       4  ...                 4
# 129879                                       1  ...                 4
#
#         Seat Comfort  Leg Room Service  Cleanliness  Food and Drink  \
# 129875             1                 4            4               4
# 129876             2                 5            2               2
# 129877             3                 4            3               3
# 129878             4                 5            3               3
# 129879             2                 4            2               2
#
#         In-flight Service  In-flight Wifi Service  In-flight Entertainment  \
# 129875                  5                       4                        4
# 129876                  4                       3                        2
# 129877                  4                       2                        3
# 129878                  4                       5                        3
# 129879                  2                       3                        2
#
#         Baggage Handling             Satisfaction
# 129875                 4  Neutral or Dissatisfied
# 129876                 5  Neutral or Dissatisfied
# 129877                 5  Neutral or Dissatisfied
# 129878                 5                Satisfied
# 129879                 1  Neutral or Dissatisfied
#
# [5 rows x 24 columns]

# %%
# data shape
row, col = data.shape
print(f"There are {row} rows and {col} columns in the data")
# Out:
# There are 129880 rows and 24 columns in the data

# %% [markdown]
# ### 3.1. Description of data
# The below is the description of columns in the dataset. Understanding the characteristics of columns helps in better comprehending the data and its potential biases and limitations, enabling us to draw more accurate conclusions from the data.
#
#
# **Table 1. Description of data**
#
# | Column             | Data Type  | Description                                                                     |
# |--------------------|------------|---------------------------------------------------------------------------------|
# | ID                 | int64      | Unique flight passenger identifier, not required in the analysis                |
# | Gender             | category   | Gender of the flight passenger, binary variable (men/women)                     |
# | Age                | int64      | Age of the flight passenger                                                     |
# | Customer Type      | category   | Type of flight passenger, binary variable (first-time/returning)                |
# | Type of Travel     | category   | Travel purpose, binary variable (business/personal)                             |
# | Class              | category   | Passenger seat class for the air travel, three types - business, economy and economy plus                           |
# | Flight Distance    | int64      | Flight distance in miles                                                        |
# | Departure Delay    | int64      | Departure delay in minutes                                                      |
# | Arrival Delay      | float64    | The data type of Arrival Delay is float64, but it can be converted to int64 as measurement unit is in minutes.              |
# | Departure and Arrival Time Convenience | int64   | Satisfaction score for flight departure and arrival convenience from 1 to 5, 0 means "not applicable"                                          |
# | Ease of Online Booking | int64 | Satisfaction score for online booking convenience from 1 to 5, 0 means "not applicable"                         |
# | Check-in Service   | int64      | Satisfaction score for check-in service experience from 1 to 5, 0 means "not applicable"   |
# | Online Boarding    | int64      | Satisfaction score for online boarding experience from 1 to 5, 0 means "not applicable"    |
# | Gate Location      | int64      | Satisfaction score for gate location in the airport from 1 to 5, 0 means "not applicable"  |
# | On-board Service   | int64      | Satisfaction score for on-boarding service experience from 1 to 5, 0 means "not applicable"|
# | Seat Comfort       | int64      | Satisfaction score for airplane seat comfort from 1 to 5, 0 means "not applicable"         |
# | Leg Room Service   | int64      | Satisfaction score for leg room of airplane seat from 1 to 5, 0 means "not applicable"     |
# | Cleanliness        | int64      | Satisfaction score for sanitation of airplane from 1 to 5, 0 means "not applicable"        |
# | Food and Drink     | int64      | Satisfaction score for food and drinks on the airplane from 1 to 5, 0 means "not applicable" |
# | In-flight Service  | int64      | Satisfaction score for in-flight service experience from 1 to 5, 0 means "not applicable"  |
# | In-flight Wifi Service | int64  | Satisfaction score for in-flight Wifi service from 1 to 5, 0 means "not applicable"        |
# | In-flight Entertainment | int64 | Satisfaction score for in-flight entertainment from 1 to 5, 0 means "not applicable"       |
# | Baggage Handling   | int64      | Satisfaction score for baggage handling from the air company from 1 to 5, 0 means "not applicable"|
# | Satisfaction       | category   | Overall satisfaction with the airline, binary variable (satisfied/neutral or dissatisfied) |

# %%
## information and descriptive statistical dataframes 

# Drop ID column - unnecessary columns
data.drop('ID', axis=1, inplace = True)

# create two dataframes - a general information and a descriptive statistics 
info_df = (pd.DataFrame({'Features':data.columns,'Non Null Count':data.count(), 'Null Count': data.isnull().sum(), 'Datatypes':data.dtypes,})
        .sort_values(by='Datatypes').reset_index(drop = True))
stats = data.describe(include = 'all').T.reset_index()


# merge two dataframes
tota = pd.merge( info_df,stats, right_on = 'index',left_on = 'Features',how = 'inner').drop(columns = ['index', 'count']).round(0)
tota = tota.fillna(0)


# color palette for visualisations
colors = ['#f6f5f5','#fe346e','#512b58','#2c003e']
tota.style.bar(subset = ['mean', 'std', 'min', '25%','50%','75%', 'max'],axis = 1 ,color = colors[2])\
    .format({'mean':"{:20,.0f}", 
             'std':"{:20,.0f}", 
             'min':"{:20,.0f}", 
             '25%':"{:20,.0f}",
             '50%':"{:20,.0f}",
             '75%':"{:20,.0f}", 
             'max':"{:20,.0f}"})\
    .format({"Features": lambda x:  x.upper()},
           )\
    .set_properties(**{'background-color': '#f9f9f9',                                                   
                                    'color': 'black',                       
                                    'border-color': 'white'})\
    .hide_index()
# Out:
# <style type="text/css">
# #T_8f26f_row0_col0, #T_8f26f_row0_col1, #T_8f26f_row0_col2, #T_8f26f_row0_col3, #T_8f26f_row0_col4, #T_8f26f_row0_col5, #T_8f26f_row0_col6, #T_8f26f_row1_col0, #T_8f26f_row1_col1, #T_8f26f_row1_col2, #T_8f26f_row1_col3, #T_8f26f_row1_col4, #T_8f26f_row1_col5, #T_8f26f_row1_col6, #T_8f26f_row2_col0, #T_8f26f_row2_col1, #T_8f26f_row2_col2, #T_8f26f_row2_col3, #T_8f26f_row2_col4, #T_8f26f_row2_col5, #T_8f26f_row2_col6, #T_8f26f_row3_col0, #T_8f26f_row3_col1, #T_8f26f_row3_col2, #T_8f26f_row3_col3, #T_8f26f_row3_col4, #T_8f26f_row3_col5, #T_8f26f_row3_col6, #T_8f26f_row4_col0, #T_8f26f_row4_col1, #T_8f26f_row4_col2, #T_8f26f_row4_col3, #T_8f26f_row4_col4, #T_8f26f_row4_col5, #T_8f26f_row4_col6, #T_8f26f_row5_col0, #T_8f26f_row5_col1, #T_8f26f_row5_col2, #T_8f26f_row5_col3, #T_8f26f_row5_col4, #T_8f26f_row5_col5, #T_8f26f_row5_col6, #T_8f26f_row6_col0, #T_8f26f_row6_col1, #T_8f26f_row6_col2, #T_8f26f_row6_col3, #T_8f26f_row6_col4, #T_8f26f_row6_col5, #T_8f26f_row6_col6, #T_8f26f_row7_col0, #T_8f26f_row7_col1, #T_8f26f_row7_col2, #T_8f26f_row7_col3, #T_8f26f_row7_col4, #T_8f26f_row7_col5, #T_8f26f_row7_col6, #T_8f26f_row8_col0, #T_8f26f_row8_col1, #T_8f26f_row8_col2, #T_8f26f_row8_col3, #T_8f26f_row8_col4, #T_8f26f_row8_col5, #T_8f26f_row8_col6, #T_8f26f_row9_col0, #T_8f26f_row9_col1, #T_8f26f_row9_col2, #T_8f26f_row9_col3, #T_8f26f_row9_col4, #T_8f26f_row9_col5, #T_8f26f_row9_col6, #T_8f26f_row10_col0, #T_8f26f_row10_col1, #T_8f26f_row10_col2, #T_8f26f_row10_col3, #T_8f26f_row10_col4, #T_8f26f_row10_col5, #T_8f26f_row10_col6, #T_8f26f_row11_col0, #T_8f26f_row11_col1, #T_8f26f_row11_col2, #T_8f26f_row11_col3, #T_8f26f_row11_col4, #T_8f26f_row11_col5, #T_8f26f_row11_col6, #T_8f26f_row12_col0, #T_8f26f_row12_col1, #T_8f26f_row12_col2, #T_8f26f_row12_col3, #T_8f26f_row12_col4, #T_8f26f_row12_col5, #T_8f26f_row12_col6, #T_8f26f_row13_col0, #T_8f26f_row13_col1, #T_8f26f_row13_col2, #T_8f26f_row13_col3, #T_8f26f_row13_col4, #T_8f26f_row13_col5, #T_8f26f_row13_col6, #T_8f26f_row14_col0, #T_8f26f_row14_col1, #T_8f26f_row14_col2, #T_8f26f_row14_col3, #T_8f26f_row14_col4, #T_8f26f_row14_col5, #T_8f26f_row14_col6, #T_8f26f_row15_col0, #T_8f26f_row15_col1, #T_8f26f_row15_col2, #T_8f26f_row15_col3, #T_8f26f_row15_col4, #T_8f26f_row15_col5, #T_8f26f_row15_col6, #T_8f26f_row16_col0, #T_8f26f_row16_col1, #T_8f26f_row16_col2, #T_8f26f_row16_col3, #T_8f26f_row16_col4, #T_8f26f_row16_col5, #T_8f26f_row16_col6, #T_8f26f_row17_col0, #T_8f26f_row17_col1, #T_8f26f_row17_col2, #T_8f26f_row17_col3, #T_8f26f_row17_col4, #T_8f26f_row17_col5, #T_8f26f_row17_col6, #T_8f26f_row18_col0, #T_8f26f_row18_col1, #T_8f26f_row18_col2, #T_8f26f_row18_col3, #T_8f26f_row18_col4, #T_8f26f_row18_col5, #T_8f26f_row18_col6, #T_8f26f_row19_col0, #T_8f26f_row19_col1, #T_8f26f_row19_col2, #T_8f26f_row19_col3, #T_8f26f_row19_col4, #T_8f26f_row19_col5, #T_8f26f_row19_col6, #T_8f26f_row20_col0, #T_8f26f_row20_col1, #T_8f26f_row20_col2, #T_8f26f_row20_col3, #T_8f26f_row20_col4, #T_8f26f_row20_col5, #T_8f26f_row20_col6, #T_8f26f_row21_col0, #T_8f26f_row21_col1, #T_8f26f_row21_col2, #T_8f26f_row21_col3, #T_8f26f_row21_col4, #T_8f26f_row21_col5, #T_8f26f_row21_col6, #T_8f26f_row22_col0, #T_8f26f_row22_col1, #T_8f26f_row22_col2, #T_8f26f_row22_col3, #T_8f26f_row22_col4, #T_8f26f_row22_col5, #T_8f26f_row22_col6 {
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_8f26f_row0_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #512b58 65.1%, transparent 65.1%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_8f26f_row0_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #512b58 27.0%, transparent 27.0%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_8f26f_row0_col9, #T_8f26f_row1_col9, #T_8f26f_row2_col9, #T_8f26f_row3_col9, #T_8f26f_row4_col9, #T_8f26f_row6_col9, #T_8f26f_row7_col9, #T_8f26f_row8_col9, #T_8f26f_row9_col9, #T_8f26f_row9_col10, #T_8f26f_row9_col11, #T_8f26f_row11_col9, #T_8f26f_row12_col9, #T_8f26f_row13_col9, #T_8f26f_row15_col9, #T_8f26f_row16_col9, #T_8f26f_row17_col9, #T_8f26f_row17_col10, #T_8f26f_row17_col11, #T_8f26f_row18_col7, #T_8f26f_row18_col8, #T_8f26f_row18_col9, #T_8f26f_row18_col10, #T_8f26f_row18_col11, #T_8f26f_row18_col12, #T_8f26f_row18_col13, #T_8f26f_row19_col7, #T_8f26f_row19_col8, #T_8f26f_row19_col9, #T_8f26f_row19_col10, #T_8f26f_row19_col11, #T_8f26f_row19_col12, #T_8f26f_row19_col13, #T_8f26f_row20_col7, #T_8f26f_row20_col8, #T_8f26f_row20_col9, #T_8f26f_row20_col10, #T_8f26f_row20_col11, #T_8f26f_row20_col12, #T_8f26f_row20_col13, #T_8f26f_row21_col7, #T_8f26f_row21_col8, #T_8f26f_row21_col9, #T_8f26f_row21_col10, #T_8f26f_row21_col11, #T_8f26f_row21_col12, #T_8f26f_row21_col13, #T_8f26f_row22_col7, #T_8f26f_row22_col8, #T_8f26f_row22_col9, #T_8f26f_row22_col10, #T_8f26f_row22_col11, #T_8f26f_row22_col12, #T_8f26f_row22_col13 {
#   width: 10em;
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_8f26f_row0_col10, #T_8f26f_row1_col10, #T_8f26f_row2_col10, #T_8f26f_row3_col10, #T_8f26f_row4_col10, #T_8f26f_row7_col10, #T_8f26f_row8_col10, #T_8f26f_row12_col10, #T_8f26f_row13_col10, #T_8f26f_row15_col10, #T_8f26f_row16_col10 {
#   width: 10em;
#   background: linear-gradient(90deg, #512b58 40.0%, transparent 40.0%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_8f26f_row0_col11, #T_8f26f_row4_col11, #T_8f26f_row5_col10, #T_8f26f_row6_col10, #T_8f26f_row6_col11, #T_8f26f_row7_col11, #T_8f26f_row8_col11, #T_8f26f_row11_col10, #T_8f26f_row12_col11, #T_8f26f_row14_col12, #T_8f26f_row15_col11, #T_8f26f_row16_col11 {
#   width: 10em;
#   background: linear-gradient(90deg, #512b58 60.0%, transparent 60.0%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_8f26f_row0_col12, #T_8f26f_row1_col11, #T_8f26f_row1_col12, #T_8f26f_row2_col11, #T_8f26f_row3_col11, #T_8f26f_row3_col12, #T_8f26f_row4_col12, #T_8f26f_row5_col11, #T_8f26f_row6_col12, #T_8f26f_row7_col12, #T_8f26f_row8_col12, #T_8f26f_row11_col11, #T_8f26f_row12_col12, #T_8f26f_row13_col11, #T_8f26f_row13_col12, #T_8f26f_row15_col12, #T_8f26f_row16_col12 {
#   width: 10em;
#   background: linear-gradient(90deg, #512b58 80.0%, transparent 80.0%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_8f26f_row0_col13, #T_8f26f_row1_col13, #T_8f26f_row2_col12, #T_8f26f_row2_col13, #T_8f26f_row3_col13, #T_8f26f_row4_col13, #T_8f26f_row5_col12, #T_8f26f_row5_col13, #T_8f26f_row6_col13, #T_8f26f_row7_col13, #T_8f26f_row8_col13, #T_8f26f_row9_col13, #T_8f26f_row10_col13, #T_8f26f_row11_col12, #T_8f26f_row11_col13, #T_8f26f_row12_col13, #T_8f26f_row13_col13, #T_8f26f_row14_col13, #T_8f26f_row15_col13, #T_8f26f_row16_col13, #T_8f26f_row17_col13 {
#   width: 10em;
#   background: linear-gradient(90deg, #512b58 100.0%, transparent 100.0%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_8f26f_row1_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #512b58 67.0%, transparent 67.0%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_8f26f_row1_col8, #T_8f26f_row15_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #512b58 26.3%, transparent 26.3%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_8f26f_row2_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #512b58 68.8%, transparent 68.8%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_8f26f_row2_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #512b58 26.4%, transparent 26.4%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_8f26f_row3_col7 {
#   width: 10em;
#   background: linear-gradient(90deg, #512b58 67.7%, transparent 67.7%);
#   background-color: #f9f9f9;
#   color: black;
#   border-color: white;
# }
# #T_8f26f_row3_col8 {
#   width: 10em;
#   background: linear-gradient(90deg, #512b58 25.7%, transparent 25.7%);
#   background-color: #f9f9f9;
#   color: black;

# %% [markdown]
# The summary of data indicates
#
# - Data consist of `categorical` and `numerical` types. The categorical variables need to be handled by using LabelEncoder as ML algorithms generally cannot deal with them.
# - 393 missing values in `Arrival Delay` need to be handled.
# - `ID` column is not necessary in predicting satisfaction, so it has been removed.

# %% [markdown]
# ### 3.2. Data Visualisation

# %% [markdown]
# #### 3.2.1. Numerical features

# %%
# Departure Delay and Satisfaction
fig = plt.figure(figsize = (12,10), dpi = 60)

gs = fig.add_gridspec(10,8)
gs.update(wspace = 1, hspace = 0.05)


ax1 = fig.add_subplot(gs[1:4,0:8]) #distribution plot
ax2 = fig.add_subplot(gs[6:9, 0:8]) #hue distribution plot


# axes list
axes = [ ax1, ax2]

# setting of axes; visibility of axes and spines turn off
for ax in axes:
    ax.axes.get_yaxis().set_visible(False)
    ax.set_facecolor('#f6f5f5')
    
    for loc in ['left', 'right', 'top', 'bottom']:
        ax.spines[loc].set_visible(False)

fig.patch.set_facecolor('#f6f5f5')
        


# distribution plots ---- only single variable, to show an overall distribution of a single variable 

sns.kdeplot(data = data, x = 'Departure Delay', ax = ax1, shade = True, color = '#2c003e', alpha = 1, )
ax1.set_xlabel('Departure Delay in Minute', fontdict = {'font':'Serif', 'color': 'black', 'size': 16,'weight':'bold' })
ax1.text(-36,0.072,'Overall Departure Delay Distribution', {'font':'Serif', 'color': 'black','weight':'bold','size':24}, alpha = 0.9)
ax1.text(-23,0.057, 'The vast majority of flights departs on time. \nHowever, there are some signs of massive outliers\nwhich need to be handled', 
        {'font':'Serif', 'size':'14','color': 'black'})
ax1.text(460,0.045, 'Total',{'font':'Serif', 'size':'14','color': '#2c003e','weight':'bold'})
ax1.text(580,0.045, '=',{'font':'Serif', 'size':'14','color': 'black','weight':'bold'})
ax1.text(625,0.045, 'Satisfied',{'font':'Serif', 'size':'14','color': '#fe346e','weight':'bold'})
ax1.text(820,0.045, '+',{'font':'Serif', 'size':'14','color': 'black','weight':'bold'})
ax1.text(870,0.045, 'Neutral or Dissatisfied',{'font':'Serif', 'size':'14','color': '#512b58','weight':'bold'})



# distribution plots with hue of satisfaction, to show the distribution of a variable with regards to target variable


sns.kdeplot(data = data[data['Satisfaction'] == "Neutral or Dissatisfied"], x = 'Departure Delay',ax = ax2, shade = True,  alpha = 1, color = '#512b58' )
sns.kdeplot(data = data[data['Satisfaction'] == "Satisfied"], x = 'Departure Delay',ax = ax2, shade = True,  alpha = 0.8, color = '#fe346e')

ax2.set_xlabel('Departure Delay in Minute', fontdict = {'font':'Serif', 'color': 'black', 'weight':'bold','size': 16})

ax2.text(-23,0.087,'Distribution of Departure Delay by Satisfaction', {'font':'Serif', 'weight':'bold','color': 'black', 'size':24}, alpha= 0.9)
ax2.text(-23,0.071,'It is clear that passengers are satisfied,\nwhen the planes leaves on time or when the delay is short', {'font':'Serif', 'color': 'black', 'size':14})
ax2.text(625,0.057, 'Satisfied ', {'font': 'Serif','weight':'bold','size': '14','weight':'bold','style':'normal', 'color':'#fe346e'})
ax2.text(835,0.057, '|', {'color':'black' , 'size':'14', 'weight': 'bold'})
ax2.text(870,0.057, 'Neutral or Dissatisfied', {'font': 'Serif','weight':'bold', 'size': '14','style':'normal', 'weight':'bold','color':'#512b58'})

# Figure numbering
plt.suptitle('Figure 1. Departure Delay and Satisfaction', fontsize=16, font='Serif',  fontweight='bold', x=0.38, y=0.12)
fig.show()

# %% [markdown]
# An insight:
#
# - The distribution is highly skewed.
# - Most of flights departs on time but there are some massive outliers.

# %%
# Departure Delay and Satisfaction
fig = plt.figure(figsize = (12,10), dpi = 60)

gs = fig.add_gridspec(10,8)
gs.update(wspace = 1, hspace = 0.05)


ax1 = fig.add_subplot(gs[1:4,0:8]) #distribution plot
ax2 = fig.add_subplot(gs[6:9, 0:8]) #hue distribution plot


# axes list
axes = [ ax1, ax2]

# setting of axes; visibility of axes and spines turn off
for ax in axes:
    ax.axes.get_yaxis().set_visible(False)
    ax.set_facecolor('#f6f5f5')
    
    for loc in ['left', 'right', 'top', 'bottom']:
        ax.spines[loc].set_visible(False)

fig.patch.set_facecolor('#f6f5f5')
        


# distribution plots ---- only single variable, to show an overall distribution of a single variable 

sns.kdeplot(data = data, x = 'Arrival Delay', ax = ax1, shade = True, color = '#2c003e', alpha = 1, )
ax1.set_xlabel('Arrival Delay in Minute', fontdict = {'font':'Serif', 'color': 'black', 'size': 16,'weight':'bold' })
ax1.text(-36,0.072,'Overall Arrival Delay Distribution', {'font':'Serif', 'color': 'black','weight':'bold','size':24}, alpha = 0.9)
ax1.text(-23,0.057, 'The vast majority of flights arrives on time. \nHowever, there are signs of significant outliers\nwhich require attention.', 
        {'font':'Serif', 'size':'14','color': 'black'})
ax1.text(460,0.045, 'Total',{'font':'Serif', 'size':'14','color': '#2c003e','weight':'bold'})
ax1.text(580,0.045, '=',{'font':'Serif', 'size':'14','color': 'black','weight':'bold'})
ax1.text(625,0.045, 'Satisfied',{'font':'Serif', 'size':'14','color': '#fe346e','weight':'bold'})
ax1.text(820,0.045, '+',{'font':'Serif', 'size':'14','color': 'black','weight':'bold'})
ax1.text(870,0.045, 'Neutral or Dissatisfied',{'font':'Serif', 'size':'14','color': '#512b58','weight':'bold'})



# distribution plots with hue of satisfaction, to show the distribution of a variable with regards to target variable


sns.kdeplot(data = data[data['Satisfaction'] == "Neutral or Dissatisfied"], x = 'Arrival Delay',ax = ax2, shade = True,  alpha = 1, color = '#512b58' )
sns.kdeplot(data = data[data['Satisfaction'] == "Satisfied"], x = 'Arrival Delay',ax = ax2, shade = True,  alpha = 0.8, color = '#fe346e')

ax2.set_xlabel('Arrival Delay in Minute', fontdict = {'font':'Serif', 'color': 'black', 'weight':'bold','size': 16})

ax2.text(-23,0.087,'Distribution of Arrival Delay by Satisfaction', {'font':'Serif', 'weight':'bold','color': 'black', 'size':24}, alpha= 0.9)
ax2.text(-23,0.071,'It is clear that passengers are satisfied \nwhen the planes arrive on time or when the delay is short.', {'font':'Serif', 'color': 'black', 'size':14})
ax2.text(625,0.057, 'Satisfied ', {'font': 'Serif','weight':'bold','size': '14','weight':'bold','style':'normal', 'color':'#fe346e'})
ax2.text(835,0.057, '|', {'color':'black' , 'size':'14', 'weight': 'bold'})
ax2.text(870,0.057, 'Neutral or Dissatisfied', {'font': 'Serif','weight':'bold', 'size': '14','style':'normal', 'weight':'bold','color':'#512b58'})

# Figure numbering
plt.suptitle('Figure 2. Arrival Delay and Satisfaction', fontsize=16, font='Serif',  fontweight='bold', x=0.36, y=0.12)
fig.show()

# %% [markdown]
# An insight:
#
# - The distribution is highly skewed which is similar to that of `Departure Delay`.
# - Most of flights departs on time but there are some significant outliers.

# %%
# Age and Satisfaction
fig = plt.figure(figsize = (12,10), dpi = 60)

gs = fig.add_gridspec(10,8)
gs.update(wspace = 1, hspace = 0.05)


ax1 = fig.add_subplot(gs[1:4,0:8]) #distribution plot
ax2 = fig.add_subplot(gs[6:9, 0:8]) #hue distribution plot


# axes list
axes = [ ax1, ax2]

# setting of axes; visibility of axes and spines turn off
for ax in axes:
    ax.axes.get_yaxis().set_visible(False)
    ax.set_facecolor('#f6f5f5')
    
    for loc in ['left', 'right', 'top', 'bottom']:
        ax.spines[loc].set_visible(False)

fig.patch.set_facecolor('#f6f5f5')
        


# distribution plots ---- only single variable, to show an overall distribution of a single variable

sns.kdeplot(data = data, x = 'Age', ax = ax1, shade = True, color = '#2c003e', alpha = 1, )
ax1.set_xlabel('Age of a person', fontdict = {'font':'Serif', 'color': 'black', 'size': 16,'weight':'bold' })
ax1.text(-17,0.037,'Overall Age Distribution', {'font':'Serif', 'color': 'black','weight':'bold','size':24}, alpha = 0.9)
ax1.text(-17,0.032, 'The distribution of Age looks almost like a normal distribution.', 
        {'font':'Serif', 'size':'14','color': 'black'})
ax1.text(53,0.025, 'Total',{'font':'Serif', 'size':'14','color': '#2c003e','weight':'bold'})
ax1.text(59,0.025, '=',{'font':'Serif', 'size':'14','color': 'black','weight':'bold'})
ax1.text(62,0.025, 'Satisfied',{'font':'Serif', 'size':'14','color': '#fe346e','weight':'bold'})
ax1.text(72.5,0.025, '+',{'font':'Serif', 'size':'14','color': 'black','weight':'bold'})
ax1.text(75,0.025, 'Neutral or Dissatisfied',{'font':'Serif', 'size':'14','color': '#512b58','weight':'bold'})



# distribution plots with hue of satisfaction, to show the distribution of a variable with regards to target variable


sns.kdeplot(data = data[data['Satisfaction'] == "Neutral or Dissatisfied"], x = 'Age',ax = ax2, shade = True,  alpha = 1, color = '#512b58' )
sns.kdeplot(data = data[data['Satisfaction'] == "Satisfied"], x = 'Age',ax = ax2, shade = True,  alpha = 0.8, color = '#fe346e')

ax2.set_xlabel('Age of a person', fontdict = {'font':'Serif', 'color': 'black', 'weight':'bold','size': 16})

ax2.text(-17,0.0435,'Distribution of Age by Satisfaction', {'font':'Serif', 'weight':'bold','color': 'black', 'size':24}, alpha= 0.9)
ax2.text(-17,0.0325,"Satisfaction was higher among middle-aged passengers,\nwhile 'Neutral or Dissatisfied' feedback were more prevalent\namong young adults and elderly.", {'font':'Serif', 'color': 'black', 'size':14})
ax2.text(60,0.027, 'Satisfied ', {'font': 'Serif','weight':'bold','size': '14','weight':'bold','style':'normal', 'color':'#fe346e'})
ax2.text(72.5,0.027, '|', {'color':'black' , 'size':'14', 'weight': 'bold'})
ax2.text(75,0.027, 'Neutral or Dissatisfied', {'font': 'Serif','weight':'bold', 'size': '14','style':'normal', 'weight':'bold','color':'#512b58'})

# Figure numbering
plt.suptitle('Figure 3. Age and Satisfaction', fontsize=16, font='Serif',  fontweight='bold', x=0.15, y=0.13)
fig.show()

# %% [markdown]
# An insight:
#
# - The distribution of age looks almost like a normal distribution, but log transformation would make it look more like a normal distribution.
# - Satisfaction was relatively higher in middle-aged passengers.

# %%
# Flight Distance and Satisfaction
fig = plt.figure(figsize = (12,10), dpi = 60)

gs = fig.add_gridspec(8,8)
gs.update(wspace = 1, hspace = 0.05, top=0.98)



ax1 = fig.add_subplot(gs[1:4,0:8]) #distribution plot
ax2 = fig.add_subplot(gs[5:8, 0:8]) #hue distribution plot


# axes list
axes = [ ax1, ax2]

# setting of axes; visibility of axes and spines turn off
for ax in axes:
    ax.axes.get_yaxis().set_visible(False)
    ax.set_facecolor('#f6f5f5')
    
    for loc in ['left', 'right', 'top', 'bottom']:
        ax.spines[loc].set_visible(False)

fig.patch.set_facecolor('#f6f5f5')
        
# distribution plots ---- only single variable, to show an overall distribution of a single variable

sns.kdeplot(data = data, x = 'Flight Distance', ax = ax1, shade = True, color = '#2c003e', alpha = 1)
ax1.set_xlabel('Flight Distance in Miles', fontdict = {'font':'Serif', 'color': 'black', 'size': 16,'weight':'bold' })

# adding texts to ax1
ax1.text(1200, 0.00070, 'Total', {'font':'Serif', 'size': 16,'color': '#2c003e','weight':'bold'})
ax1.text(1580, 0.00070,  '=', {'color':'black' , 'size': 16, 'weight': 'bold'})
ax1.text(1750, 0.00070, 'Satisfied', fontdict={'font':'Serif', 'color':'black', 'size': 16,'weight':'bold','style':'normal', 'color':'#fe346e'})
ax1.text(2500, 0.00070,  '+', {'color':'black' , 'size': 16, 'weight': 'bold'})
ax1.text(2650, 0.00070,  'Neutral or Dissatisfied', fontdict={'font':'Serif', 'color':'black', 'size': 16,'weight':'bold','style':'normal', 'color':'#512b58'})


# distribution plots with hue of satisfaction, to show the distribution of a variable with regards to target variable


sns.kdeplot(data = data[data['Satisfaction'] == "Neutral or Dissatisfied"], x = 'Flight Distance',ax = ax2, shade = True,  alpha = 1, color = '#512b58')
sns.kdeplot(data = data[data['Satisfaction'] == "Satisfied"], x = 'Flight Distance',ax = ax2, shade = True,  alpha = 0.8, color = '#fe346e')

ax2.set_xlabel('Flight Distance in Miles', fontdict = {'font':'Serif', 'color': 'black', 'weight':'bold','size': 16})

# adding texts to ax2
ax2.text(1700, 0.00075, 'Satisfied', fontdict={'font':'Serif', 'color':'black', 'size':16,'weight':'bold','style':'normal', 'color':'#fe346e'})
ax2.text(2470, 0.00075,  '|', {'color':'black' , 'size': 16, 'weight': 'bold'})
ax2.text(2550, 0.00075,  'Neutral or Dissatisfied', fontdict={'font':'Serif', 'color':'black', 'size':16,'weight':'bold','style':'normal', 'color':'#512b58'})

# Set titles for both plots
ax1.set_title('Overall Distribution of Flight Distance', fontdict = {'font':'Serif', 'color': 'black', 'size': 24,'weight':'bold' }, loc ='left')
ax2.set_title('Distribution of Flight Distance by Satisfaction', fontdict = {'font':'Serif', 'color': 'black', 'size': 24,'weight':'bold' },loc='left')


# Figure numbering
plt.suptitle('Figure 4. Flight Distance and Satisfaction', fontsize=16, font='Serif',  fontweight='bold', x=0.345, y=0.05)

fig.show()

# %% [markdown]
# An insight:
#
# - The distribution of flight distance looks skewed with some signs of outliers.
# - In a short-haul flight, the number of neutral or dissatisfied passengers outnumbered that of satisfactory responses.
# - Satisfied feedback is more prevalent in a long-haul flight.

# %% [markdown]
# #### 3.2.2. Ordinal features

# %% [markdown]
# There are 14 ordinal features in the dataset.

# %%
# a list of ordinal feature columns
ordinal_cols = ['Departure and Arrival Time Convenience',
 'Ease of Online Booking',
 'Check-in Service',
 'Online Boarding',
 'Gate Location',
 'On-board Service',
 'Seat Comfort',
 'Leg Room Service',
 'Cleanliness',
 'Food and Drink',
 'In-flight Service',
 'In-flight Wifi Service',
 'In-flight Entertainment',
 'Baggage Handling']

# %%
# create a function that creates count plots of ordinal variables
def plot_countplot_ordinal(data, ordinal_cols):
    # Set font properties for x/y-axis labels
    font = {'family': 'serif', 'color': 'black', 'weight': 'normal', 'size': 12}

    plt.figure(figsize=(20, 18))
    plt.suptitle('Figure 5. Count Plots of Ordinal Features', fontsize=20, font='Serif',fontweight='bold', x=0.17, y=-0.02)

    for i in range(len(ordinal_cols)):
        ax = plt.subplot(4, 4, i+1)
        sns.countplot(data=data, x=data[ordinal_cols[i]], palette=['#512b58', '#fe346e'], hue=data['Satisfaction'], ax=ax)
        ax.set_xlabel('')
        ax.set_xticklabels(ax.get_xticklabels(), fontdict=font)
        ax.set_ylabel('Count', fontdict=font)
        ax.tick_params(axis='x', labelsize=12)
        ax.tick_params(axis='y', labelsize=12)
        ax.set_title(ordinal_cols[i].title(), color='#2c003e', font='Serif', size=14)
        ax.legend(loc='best')
        for tick in ax.get_yticklabels():
            tick.set_fontname("serif")
            tick.set_fontsize(12)

    plt.subplots_adjust(hspace=0.6, wspace=0.3)
    plt.tight_layout()
    plt.show()

# %%
# See distribution of ordinal columns with respect to satisfaction
plot_countplot_ordinal(data, ordinal_cols)

# %% [markdown]
# An insight:
# - When the score was less than 3, neutral or dissatisfied responses outnumbered satisfactory feedback
# - When the score was more than 4, positive feedback was more prevalent than negative feedback except a few columns, such as "Departure and Arrival Time Convenience", "Check-in Service" and "Gate location".
# - The value of 0 meaning "not applicable" in a few columns should be handled as it is not a valid score.

# %% [markdown]
# #### 3.2.3. Categorical Variables

# %% [markdown]
# There are five categorical variables including target variable in the dataset. However, given the distribution of target variable is important, it will be covered separately.

# %%
# columns of categorical features
categorical_cols = ['Gender', 'Customer Type', 'Type of Travel', 'Class']

# %%
# create a function that creates count plots of categorical variables
def create_count_plots(data, cols, target_col, palette=['#512b58', '#fe346e']):
    '''
    Create count plots for each column in the dataframe
    
    Parameters:
    data (pd.DataFrame): dataframe containing the data
    cols (list): list of column names to be plotted
    target_col (str): name of the target column
    palette (list): list of colors to be used for plotting
    
    Returns:
    None
    '''
    font = {'family': 'serif', 'color': 'black', 'weight': 'normal', 'size': 12}
    
    plt.figure(figsize=(20, 18))
    plt.suptitle('Figure 6. Count Plots of Categorical Features', fontsize = 20,fontweight='bold', font = 'Serif', x=0.185,y=0.7)
    for i in range(len(cols)):
        ax = plt.subplot(4,4,i+1)
        sns.countplot(data=data, x=data[cols[i]], palette=palette, hue=data[target_col], ax=ax)
        ax.set_xlabel('')
        plt.subplots_adjust(hspace=0.6, wspace=0.3)
        plt.title(cols[i].title(), color='#2c003e', font='Serif', size=14)
        ax.set_xticklabels(ax.get_xticklabels(), fontdict=font)
        ax.set_ylabel('Count', fontdict=font)
        ax.set_yticklabels(ax.get_yticks(), fontdict=font)

    plt.tight_layout()

# %%
# See distribution of ordinal columns with respect to satisfaction
create_count_plots(data, categorical_cols, 'Satisfaction', ['#512b58', '#fe346e'])

# %% [markdown]
# An insight:
#
# - The number of "Neutral or Dissatisfied" passengers were more than that of "Satisfied" passengers, in both genders.
# - Many passengers were not a first-time user.
# - The number of business travelers were higher than that of personal purpose travelers.
# - Passengers on business class were more satisfied than passengers of other class.

# %% [markdown]
# #### 3.2.4. Distribution of Target

# %% [markdown]
# The distribution of our target variable is important when building a prediction model. Highly unbalanced distribution of target variable results in a poor model prediction (Branco et al., 2016). In the presence of unbalanced target variable, we need to do undersampling or oversampling.

# %%
# count target variable
x = pd.DataFrame( data.groupby(['Satisfaction'])['Satisfaction'].count())
x
# Out:
#                          Satisfaction
# Satisfaction
# Neutral or Dissatisfied         73452
# Satisfied                       56428

# %%
# visualise distribution of target variable
x = pd.DataFrame( data.groupby(['Satisfaction'])['Satisfaction'].count())

# plot
fig, ax = plt.subplots(figsize = (6,6), dpi = 70)
ax.barh([1], x.Satisfaction[1], height = 0.7, color = '#fe346e')
plt.text(-25150,-0.08, 'Neutral/\nDissatisfied',{'font': 'Serif','weight':'bold','size': '16','style':'normal', 'color':'#512b58'})
plt.text(75000,-0.08, '56%',{'font':'Serif','weight':'bold' ,'size':'16','color':'#512b58'})
ax.barh([0], x.Satisfaction[0], height = 0.7, color = '#512b58')
plt.text(-25150,1, 'Satisfied', {'font': 'Serif','weight':'bold','size': '16','style':'normal', 'color':'#fe346e'})
plt.text(57500,1, '44%',{'font':'Serif', 'weight':'bold','size':'16','color':'#fe346e'})

fig.patch.set_facecolor('#f6f5f5')
ax.set_facecolor('#f6f5f5')

plt.text(-25150,1.77, 'Distribution of Passenger\'s Satisfaction' ,{'font': 'Serif', 'size': '25','weight':'bold', 'color':'black'})
plt.text(41650,1.61, 'Satisfied', {'font': 'Serif','weight':'bold','size': '16','weight':'bold','style':'normal', 'color':'#fe346e'})
plt.text(60050,1.61, '|', {'color':'black' , 'size':'16', 'weight': 'bold'})
plt.text(61750,1.61, 'Neutral/Dissatisfied', {'font': 'Serif','weight':'bold', 'size': '16','style':'normal', 'weight':'bold','color':'#512b58'})
plt.text(-25150,1.42, 'The distribution of passenger\'s response is generally balanced \nwith slightly higher response in Neutral/Dissatisfied', 
        {'font':'Serif', 'size':'12','color': 'black'})

ax.axes.get_xaxis().set_visible(False)
ax.axes.get_yaxis().set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)


# Figure numbering
plt.title('Figure 7. Distribution of Target Variable', size = 13, x=0.08, y = -0.1, font='Serif',fontweight='bold')
# Out:
# Text(0.08, -0.1, 'Figure 7. Distribution of Target Variable')

# %% [markdown]
# Neutral or Dissatisfied feedback was slightly higher than the positive response. Yet, the distribution is quasi-equally balanced so we do not need resampling.

# %% [markdown]
# ## 4. Methods

# %% [markdown]
# **Supervised learning** involves using labelled training data to build a model or classifier, which is then evaluated on new, unseen data. The accuracy of the model is determined by comparing its predictions with the known correct answers in the labelled data (Li et al., 2017). Given the data contains labels and the goal of this paper is to accurately predict passenger satisfaction and understand important factors contributing to passenger satisfaction, **Supervised ML models** seem suitable for analysis.
#
# Methods consist of two processes: data preprocessing and building ML models.
#
# **Data preprocessing** plays a critical role in building accurate and efficient ML models.
# - Data cleaning: Handling missing values and outliers
# - Data encoding: Converting categorical variables into numerical representations
# - Data transformation and standardisation: Normalising or transforming the data to improve its distribution or make it more amenable to modeling.
# - Feature selection: Identification of the most relevant features
#
# **ML models**: **Logistic Regression (LR)**, **Classification and Regression Trees (CART)**, **Random Forest (RF)**, and **Extreme Gradient Boosting (XGBoost)** will be introduced and evaluated for their performance in predicting passenger satisfaction.

# %% [markdown]
# ### 4.1. Data preprocessing

# %% [markdown]
# #### 4.1.1. Handling missing values

# %% [markdown]
# Missing values will be checked and then replaced by median values as it is robust to outliers.

# %%
# check number of missing values in the data

total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
missing = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing.head()
# Out:
#                          Total                                  Percent
# Arrival Delay              393                                   0.0030
# Gender                       0                                   0.0000
# Gate Location                0                                   0.0000
# Baggage Handling             0                                   0.0000
# In-flight Entertainment      0                                   0.0000

# %%
# Visualisation of missing values

# color scheme
color = ['grey','grey','grey','grey','grey','grey','grey','grey','grey','grey','grey',
        'grey','grey','grey','grey','grey','grey','grey','grey','grey','grey', 'grey', '#fe346e']
fig, ax = plt.subplots(figsize = (12,4), dpi = 70)
fig.patch.set_facecolor('#f6f5f5')
ax.set_facecolor('#f6f5f5')

# displaying bar graphs in a descending order
msno.bar(data, sort = 'descending', 
         color = color, 
         ax = ax, fontsize =8,
         labels = 'off',filter = 'top')

# adding texts
ax.text(-1,1.35,'Visualisation of Missing Values in The Dataset',{'font': 'Serif', 'size': 24,  'color':'black'},alpha = 0.9)
ax.text(-1,1.2,'There are 129880 datapoints in our data.\nOnly "Arrival Delay" feature has null values, which need to be handled.',{'font': 'Serif', 'size': 12,  'color':'black'}, alpha = 0.7)

ax.set_xticklabels(ax.get_xticklabels(),rotation = 90, 
                   ha = 'center', **{'font': 'Serif', 'size': 14,'weight':'normal','color':'#512b58'}, alpha = 1)
ax.set_yticklabels('')
ax.spines['bottom'].set_visible(True)

# Figure numbering
plt.title('Figure 8. Visualisation of Null Vaules', size = 13, x=0.18, y = -1.55, fontweight='bold',font='Serif') 
fig.show()

# %%
# replacing missing values with median values
data['Arrival Delay'] = data['Arrival Delay'].fillna(round (data['Arrival Delay'].median(), 2))
data.isnull().sum()
# Out:
# Gender                                    0
# Age                                       0
# Customer Type                             0
# Type of Travel                            0
# Class                                     0
# Flight Distance                           0
# Departure Delay                           0
# Arrival Delay                             0
# Departure and Arrival Time Convenience    0
# Ease of Online Booking                    0
# Check-in Service                          0
# Online Boarding                           0
# Gate Location                             0
# On-board Service                          0
# Seat Comfort                              0
# Leg Room Service                          0
# Cleanliness                               0
# Food and Drink                            0
# In-flight Service                         0
# In-flight Wifi Service                    0
# In-flight Entertainment                   0
# Baggage Handling                          0
# Satisfaction                              0
# dtype: int64

# %% [markdown]
# There are no missing values in the datasets.

# %% [markdown]
# #### 4.1.2. Handling the value of 0 in ordinal features

# %% [markdown]
# The value of 0 in ordinal feature columns might affect the interpretation of standardised data. Thus, it seems reasonable to exclude rows with the value of 0 before standardising the columns to get a more accurate representation of the data.

# %%
# dropping rows which has the value of 0
data = data[(data[['Departure and Arrival Time Convenience', 'Ease of Online Booking', 'Online Boarding',
            'Leg Room Service', 'In-flight Wifi Service']] != 0).all(axis=1)]

# %% [markdown]
# #### 4.1.3. Data type conversion

# %% [markdown]
# The below procedure converts the data type and reduces the memory usage.

# %%
# converting data type 
data['Arrival Delay'] = data['Arrival Delay'].astype('int64')

categorical_colnames =  ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'Satisfaction']
for i in categorical_colnames:
    data[i] = data[i].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119577 entries, 0 to 129879
# Data columns (total 23 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   Gender                                  119577 non-null  category
#  1   Age                                     119577 non-null  int64
#  2   Customer Type                           119577 non-null  category
#  3   Type of Travel                          119577 non-null  category
#  4   Class                                   119577 non-null  category
#  5   Flight Distance                         119577 non-null  int64
#  6   Departure Delay                         119577 non-null  int64
#  7   Arrival Delay                           119577 non-null  int64
#  8   Departure and Arrival Time Convenience  119577 non-null  int64
#  9   Ease of Online Booking                  119577 non-null  int64
#  10  Check-in Service                        119577 non-null  int64
#  11  Online Boarding                         119577 non-null  int64
#  12  Gate Location                           119577 non-null  int64
#  13  On-board Service                        119577 non-null  int64
#  14  Seat Comfort                            119577 non-null  int64
#  15  Leg Room Service                        119577 non-null  int64
#  16  Cleanliness                             119577 non-null  int64
#  17  Food and Drink                          119577 non-null  int64
#  18  In-flight Service                       119577 non-null  int64
#  19  In-flight Wifi Service                  119577 non-null  int64
#  20  In-flight Entertainment                 119577 non-null  int64
#  21  Baggage Handling                        119577 non-null  int64
#  22  Satisfaction                            119577 non-null  category
# dtypes: category(5), int64(18)
# memory usage: 17.9 MB

# %% [markdown]
# #### 4.1.4. Outliers

# %% [markdown]
# The existence of outliers might affect a model's performance so they will be removed by using z-scores.

# %%
# Boxplots of features
numeric_data = data.select_dtypes(exclude=["object"])
numeric_data.plot(subplots=True, kind='box', layout=(5,5), figsize=(14,14), patch_artist=True, color=colors[1])
plt.subplots_adjust(wspace=0.5)

# Figure numbering
plt.suptitle('Figure 9. Boxplots of Numeric Features', fontsize=13, fontweight='bold', font = 'Serif', x = 0.25, y=0.25)
# Out:
# Text(0.25, 0.25, 'Figure 9. Boxplots of Numeric Features')

# %% [markdown]
# The outliers in columns of `Flight Distance`, `Departure Delay` and `Arrival Delay` are noticeable and these will be dropped by using z-score.

# %%
# create a function that filters outliers by using z-score
def filter_outliers_zscore(data, columns, std=3):
    zscore_df = data[columns].copy()
    for col in columns:
        zscore_df[col] = np.abs((data[col] - data[col].mean()) / data[col].std())
    
    print('Shape of Dataset before removing outliers: {}'.format(data.shape))
    
    outliers = data[(zscore_df > std).any(axis=1)]
    df = data.drop(index=outliers.index).reset_index(drop=True)

    print('')
    print('Removing outliers....')
    print('Number of outliers that will be dropped are: {}'.format(outliers.shape[0]))
    print('Shape of dataset after removing outliers: {}'.format(df.shape))

    return df, zscore_df

# %%
# get outlier-filtered data and z-score dataframe
columns = ["Flight Distance", "Departure Delay", "Arrival Delay"] # columns to use for filtering outliers
df, zscore_df = filter_outliers_zscore(data, columns)
# Out:
# Shape of Dataset before removing outliers: (119577, 23)
#
# Removing outliers....
# Number of outliers that will be dropped are: 2894
# Shape of dataset after removing outliers: (116683, 23)

# %%
# visualise the number of outliers in the datasets
temp = zscore_df.copy()


# if x is bigger than 3, it will be considered as an outlier and written as 0
for col in temp.columns:
    temp[col] = temp[col].apply( lambda x: np.nan if x > 3  else x )

# outliers will be counted
nullvalues = temp.isnull().sum()

# plotting outliers in each column
fig, ax = plt.subplots(figsize = (6,3), dpi = 100)
fig.patch.set_facecolor(colors[2])
ax.set_facecolor(colors[2])

for loc in  ['left','right', 'bottom', 'top']:
    ax.spines[loc].set_visible(False)
    
ax.axes.get_yaxis().set_visible(False)
#ax.axes.get_xaxis().set_visible(False)

# height of a bar is the number of outliers
ax.bar(x = nullvalues.index , height = nullvalues.values, width = 0.45, color = colors[1])

# labelling setting
for idx,pa in enumerate(ax.patches):
    ax.text(pa.get_x() + pa.get_width()/10 +0.1 , pa.get_height() + 35, pa.get_height() ,{'font':'serif', 'size':9, 'weight':'normal', 'color':'white'}, alpha = 1)
    ax.text(pa.get_x() -0.1 , -200, nullvalues.index[idx],{'font':'serif', 'size':12, 'weight':'bold', 'color':'white'}, alpha = 1)
    

fig.text(-0.1,1.11,'Detected Outliers by Z-score ', {'font':'serif', 'size':19, 'weight':'bold','color':'white'})
fig.text(-0.1,0.95,'The majority of outliers are detected from "Departure Delay" and "Arrival Delay",\nwhile there are a relatively small number of outliers identified in "Flight Distance".', {'font':'serif', 'size':10, 'weight':'normal','color':'white'}, alpha = 0.95)

ax.set_xticks(ticks = '')

# Figure numbering
plt.title('Figure 10. Visualisation of Outliers', fontsize=13, fontweight='bold',x=0.08, y=-0.3, color = 'white', font = 'Serif')

fig.show()

# %% [markdown]
# #### 4.1.5. Filtering business air travelers

# %%
business = df[df['Type of Travel'] == 'Business']
print('Number of business travelers: {}'.format(business.shape[0]))
# Out:
# Number of business travelers: 80648

# %% [markdown]
# ### 4.2. Feature engineering

# %% [markdown]
# #### 4.2.1. Log transformation

# %% [markdown]
# Log transformation will be applied to numerical features to reduce the skewness in the distribution.

# %%
# log transformation of skewed numerical features  
df_copy = business.copy()

df_copy['Age'] = df_copy['Age'].apply(lambda x: np.log(x))
df_copy['Flight Distance'] = df_copy['Flight Distance'].apply(lambda x: np.log(x))
df_copy['Departure Delay'] = df_copy['Departure Delay'].apply(lambda x: np.log(x))
df_copy['Arrival Delay'] = df_copy['Arrival Delay'].apply(lambda x: np.log(x))

# %% [markdown]
# #### 4.2.2. Encoding and normalisation of data

# %% [markdown]
# Categorical features will be encoded by using LabelEncoder, and then all features will be normalised by using MinMaxScaler. This scaler scales the data to a specified range (usually 0 to 1), which is suitable for data that is not normally distributed and has outliers.

# %%
# preprocessing - label enconding and numerical value scaling
le = LabelEncoder()
mm = MinMaxScaler()

## label encoding of categorical features
for col in df_copy.columns:
    df_copy[col] = le.fit_transform(df_copy[col])
    
cols = df_copy.columns

## normalising features with MinMaxScaler
df_copy[cols] = mm.fit_transform(df_copy[cols])

# %% [markdown]
# #### 4.2.3. Correlation map

# %% [markdown]
# The correlation map provides a numerical representation of the correlations between variables, which are displayed as correlation coefficients. This can help you identify which features have a strong linear relationship with the target variable and which ones do not. However, it is important to keep in mind that correlation does not imply causation.

# %%
# correlation map for all the features
np.random.seed(42)

df_corr = df_copy.corr()
mask = np.triu(np.ones_like(df_corr, dtype=np.bool))
mask[np.diag_indices_from(mask)] = False

fig, ax = plt.subplots(figsize = (12,16))
fig.patch.set_facecolor('#f6f5f5')
ax.set_facecolor('#f6f5f5')

colors = ['#f6f5f5','#512b58','#fe346e']
colormap = matplotlib.colors.LinearSegmentedColormap.from_list("", colors)

# plot heatmap
sns.heatmap(df_corr, mask=mask, annot=True, fmt=".2f",cmap = colormap,
           vmin=-0.5, vmax=1.0, cbar_kws={"shrink": .5, }, ax = ax, cbar = True,
           linewidth = 1,linecolor = '#f6f5f5', square = True,annot_kws = {'font':'serif', 'size':10, 'color':'black'} )



# yticks
ax.tick_params(axis = 'y', rotation=0)
xticks = ['Gender', 'Age','Customer Type', 'Type of Travel', 'Class', 'Flight Distance', 'Departure Delay', 'Arrival Delay', 'Departure and Arrival Time Convenience',
          'Ease of Online Booking','Check-in Service','Online Boarding','Gate Location', 'On-board Service', 'Seat Comfort', 'Leg Room Service',
         'Cleanliness', 'Food and Drink', 'In-flight Service', 'In-flight Wifi Service', 'In-flight Entertainment', 'Baggage Handling', 'Satisfaction']
yticks = ['Gender', 'Age','Customer Type', 'Type of Travel', 'Class', 'Flight Distance', 'Departure Delay', 'Arrival Delay', 'Departure and Arrival Time Convenience',
          'Ease of Online Booking','Check-in Service','Online Boarding','Gate Location', 'On-board Service', 'Seat Comfort', 'Leg Room Service',
         'Cleanliness', 'Food and Drink', 'In-flight Service', 'In-flight Wifi Service', 'In-flight Entertainment', 'Baggage Handling', 'Satisfaction']

ax.set_xticklabels(xticks, fontdict={'font': 'Serif', 'size': 10, 'weight': 'bold'}, rotation=90, alpha=0.9)
ax.set_yticklabels(yticks, fontdict={'font': 'Serif', 'size': 10, 'weight': 'bold'}, rotation=0, alpha=0.9)

ax.text(-3.5,-1.1, 'Correlation Map of Features',{'font':'serif', 'size': 24, 'weight':'bold'}, alpha = 0.9)
ax.text(-3.5,-0.405, 'A Glance on feature correlation for processed feature data.',{'font':'serif', 'size': 12, 'weight':'normal'}, alpha = 0.8)

ax.text(9,5, 'The highest positive correlation can be found between \nDeparture Delay and Arrival Delay,\nwhile the lowest can be found between Flight Distance \nand Class.',{'font':'serif', 'size': 9, 'weight':'bold'},alpha = 0.7)
ax.text(9,3.1, 'Insight:',{'font':'serif', 'size': 12, 'weight':'bold'},alpha = 0.7)

# Figure numbering
plt.title('Figure 11. Correlation Map', fontsize=13, fontweight='bold',x=-0.25, y=-0.55, font = 'Serif')

fig.show()

# %%
# Calculate the correlation coefficients with respect to 'Satisfaction'
corr_coef = round(abs(df_corr['Satisfaction'] * 100).sort_values(ascending=False), 2)
corr_coef
# Out:
# Satisfaction                                                             100.0000
# Online Boarding                                                           61.4500
# In-flight Entertainment                                                   54.8400
# On-board Service                                                          47.3100
# Seat Comfort                                                              46.5100
# Customer Type                                                             44.2200
# Cleanliness                                                               42.5400
# Leg Room Service                                                          38.8400
# Baggage Handling                                                          37.8100
# In-flight Service                                                         37.3400
# Check-in Service                                                          36.1100
# Class                                                                     34.2200
# In-flight Wifi Service                                                    32.6400
# Food and Drink                                                            27.1900
# Flight Distance                                                           23.7300
# Age                                                                       20.7500
# Ease of Online Booking                                                    13.3500
# Arrival Delay                                                              9.3500
# Departure and Arrival Time Convenience                                     8.9000
# Departure Delay                                                            7.6300
# Gender                                                                     2.2800
# Gate Location                                                              1.7700
# Type of Travel                                                                NaN
# Name: Satisfaction, dtype: float64

# %%
# draw correlation coefficient regarding Satisfaction
plt.figure(figsize=(10, 8))
corr = abs(df_corr['Satisfaction'][1:]).sort_values(ascending=False)
sns.barplot(x=corr.index, y=corr, palette='Blues_d')
plt.xticks(rotation=90)
plt.ylabel('Correlation Coefficient')
# Figure numbering
plt.title('Figure 12. Correlation Coefficients with Respect to Satisfaction', fontsize=13, fontweight='bold',x=0.37, y=-0.6, font = 'Serif')
plt.show()

# %% [markdown]
# These coefficients indicate how closely related each feature is to the target variable `Satisfaction`. This is useful when building a ML model because it helps identify which features are most strongly related to the target variable. Therefore, it can help us decide which features to include or exclude from the model.
#
# The column with the strongest correlation with `Satisfaction` is `Online Boarding` with a coefficient of 0.6145, followed by `In-flight Entertainment` and `On-board Service` with coefficients of 0.5484 and 0.4731, respectively.

# %%
# select features with coefficients bigger than 0.2
corr_coef_over_20 = corr_coef[corr_coef > 20]

df_final = df_copy[corr_coef_over_20.index.tolist()]
df_final
# Out:
#                                    Satisfaction  \
# 0                                        0.0000
# 1                                        1.0000
# 2                                        1.0000
# 3                                        1.0000
# 4                                        1.0000
# ...                                         ...
# 116670                                   0.0000
# 116671                                   0.0000
# 116672                                   0.0000
# 116673                                   0.0000
# 116674                                   1.0000
#
#                                 Online Boarding  \
# 0                                        0.5000
# 1                                        1.0000
# 2                                        1.0000
# 3                                        0.7500
# 4                                        1.0000
# ...                                         ...
# 116670                                   0.2500
# 116671                                   0.5000
# 116672                                   0.2500
# 116673                                   0.2500
# 116674                                   0.7500
#
#                         In-flight Entertainment  \
# 0                                        1.0000
# 1                                        1.0000
# 2                                        0.6000
# 3                                        1.0000
# 4                                        0.6000
# ...                                         ...
# 116670                                   0.4000
# 116671                                   0.8000
# 116672                                   0.8000
# 116673                                   1.0000
# 116674                                   0.8000
#
#                                On-board Service  \
# 0                                        0.6000
# 1                                        1.0000
# 2                                        0.6000
# 3                                        1.0000
# 4                                        0.6000
# ...                                         ...
# 116670                                   0.2000
# 116671                                   0.4000
# 116672                                   0.4000
# 116673                                   0.4000
# 116674                                   1.0000
#
#                                    Seat Comfort  \
# 0                                        1.0000
# 1                                        0.7500
# 2                                        1.0000
# 3                                        1.0000
# 4                                        0.7500
# ...                                         ...
# 116670                                   0.2500
# 116671                                   0.7500
# 116672                                   0.7500
# 116673                                   1.0000
# 116674                                   0.7500
#
#                                   Customer Type  \
# 0                                        0.0000
# 1                                        1.0000
# 2                                        1.0000
# 3                                        1.0000
# 4                                        1.0000
# ...                                         ...
# 116670                                   1.0000
# 116671                                   1.0000
# 116672                                   0.0000
# 116673                                   0.0000
# 116674                                   1.0000
#
#                                     Cleanliness  \
# 0                                        1.0000
# 1                                        1.0000
# 2                                        1.0000
# 3                                        0.8000
# 4                                        1.0000
# ...                                         ...
# 116670                                   0.4000
# 116671                                   0.8000
# 116672                                   0.8000
# 116673                                   1.0000
# 116674                                   0.8000
#
#                                Leg Room Service  \
# 0                                        0.2500
# 1                                        1.0000
# 2                                        0.5000
# 3                                        1.0000
# 4                                        0.7500
# ...                                         ...
# 116670                                   0.2500
# 116671                                   1.0000
# 116672                                   0.7500
# 116673                                   0.0000
# 116674                                   0.0000
#
#                                Baggage Handling  \
# 0                                        1.0000
# 1                                        1.0000
# 2                                        0.5000
# 3                                        1.0000
# 4                                        0.5000
# ...                                         ...
# 116670                                   0.5000
# 116671                                   0.5000
# 116672                                   0.2500
# 116673                                   0.7500
# 116674                                   0.5000
#
#                               In-flight Service  \
# 0                                        1.0000
# 1                                        1.0000
# 2                                        0.6000
# 3                                        1.0000
# 4                                        0.6000
# ...                                         ...
# 116670                                   0.6000
# 116671                                   0.8000
# 116672                                   0.4000
# 116673                                   0.8000
# 116674                                   0.2000
#
#                                Check-in Service  \
# 0                                        0.7500
# 1                                        0.5000
# 2                                        0.7500
# 3                                        0.5000
# 4                                        0.5000
# ...                                         ...
# 116670                                   0.2500
# 116671                                   0.0000
# 116672                                   0.2500
# 116673                                   0.2500
# 116674                                   1.0000
#
#                                           Class  \
# 0                                        0.0000
# 1                                        0.0000
# 2                                        0.0000
# 3                                        0.0000
# 4                                        0.0000
# ...                                         ...
# 116670                                   1.0000
# 116671                                   1.0000
# 116672                                   0.5000
# 116673                                   0.0000
# 116674                                   1.0000
#
#                          In-flight Wifi Service  \
# 0                                        0.5000
# 1                                        0.2500
# 2                                        0.7500
# 3                                        0.2500
# 4                                        0.5000
# ...                                         ...
# 116670                                   0.2500
# 116671                                   0.5000
# 116672                                   0.2500
# 116673                                   0.2500
# 116674                                   0.7500
#
#                                  Food and Drink  \
# 0                                        1.0000
# 1                                        0.6000
# 2                                        1.0000
# 3                                        0.8000
# 4                                        0.8000
# ...                                         ...
# 116670                                   0.4000
# 116671                                   0.8000
# 116672                                   0.8000
# 116673                                   1.0000
# 116674                                   0.8000
#
#                                 Flight Distance  \
# 0                                        0.1813
# 1                                        0.1813
# 2                                        0.1894
# 3                                        0.4488
# 4                                        0.8606
# ...                                         ...
# 116670                                   0.0631
# 116671                                   0.0905
# 116672                                   0.0905
# 116673                                   0.0631
# 116674                                   0.0631
#
#                                             Age
# 0                                        0.5541
# 1                                        0.3784
# 2                                        0.4595
# 3                                        0.5811
# 4                                        0.5676
# ...                                         ...
# 116670                                   0.7703
# 116671                                   0.5405
# 116672                                   0.1757
# 116673                                   0.2162
# 116674                                   0.3378
#
# [80648 rows x 16 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80648 entries, 0 to 116674
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Satisfaction             80648 non-null  float64
#  1   Online Boarding          80648 non-null  float64
#  2   In-flight Entertainment  80648 non-null  float64
#  3   On-board Service         80648 non-null  float64
#  4   Seat Comfort             80648 non-null  float64
#  5   Customer Type            80648 non-null  float64
#  6   Cleanliness              80648 non-null  float64
#  7   Leg Room Service         80648 non-null  float64
#  8   Baggage Handling         80648 non-null  float64
#  9   In-flight Service        80648 non-null  float64
#  10  Check-in Service         80648 non-null  float64
#  11  Class                    80648 non-null  float64
#  12  In-flight Wifi Service   80648 non-null  float64
#  13  Food and Drink           80648 non-null  float64
#  14  Flight Distance          80648 non-null  float64
#  15  Age                      80648 non-null  float64
# dtypes: float64(16)
# memory usage: 10.5 MB

# %% [markdown]
# By setting a correlation coefficient of 0.2 as a threshold, we may exclude features whose coefficient is less than 0.2 as they can be less informative in predicting the target variable, and excluding them may simplify the model and improve its performance. However, it is important to understand that a low correlation coefficient does not necessarily mean a feature should be excluded from the model, as it may still provide valuable information when combined with other features.

# %% [markdown]
# ## 5. Results

# %% [markdown]
# ### 5.1. ML prediction models

# %% [markdown]
# #### 5.1.1. Data split

# %% [markdown]
# Data were split into a 75:25 ratio. 75% of the data is used for training and 25% is used for testing.

# %%
# separate target variable
X = df_final.drop(['Satisfaction'], axis=1)
y = df_final['Satisfaction']

# Split the data into train and test sets
random_state_split = 42
train_x, test_x, train_y, test_y = train_test_split(X, y,stratify=y, random_state=random_state_split)
print(train_y.value_counts())
# Out:
# 1.0000    35214
# 0.0000    25272
# Name: Satisfaction, dtype: int64

# %%
# check train target data
train_y
# Out:
# 59933                                      0.0000
# 34837                                      0.0000
# 24351                                      0.0000
# 32134                                      0.0000
# 42457                                      1.0000
#                            ...
# 108015                                     1.0000
# 32799                                      1.0000
# 100740                                     0.0000
# 49572                                      1.0000
# 111856                                     1.0000
# Name: Satisfaction, Length: 60486, dtype: float64

# %% [markdown]
# #### 5.1.2. Building a pipeline

# %%
# building a pipeline
classifiers = {
    'LR': LogisticRegression(random_state=random_state_split),
    'CART': DecisionTreeClassifier(random_state=random_state_split),
    'RF': RandomForestClassifier(random_state=random_state_split),
    'XGB': XGBClassifier(random_state=random_state_split)
}


# a dict to store the R2 of training and testing data
dict_results = dict()

# as features have already been encoded/normalised, these preprocessing processes are not included in the pipeline
for name, classifier in classifiers.items():
    pipeline = Pipeline(steps = [('classifier', classifier)])
    
    model = pipeline.fit(train_x, train_y)
    
    train_pred = model.predict(train_x)
    test_pred = model.predict(test_x)
    
    train_rmse = np.sqrt(mean_squared_error(train_y, train_pred))
    test_rmse = np.sqrt(mean_squared_error(test_y, test_pred))
    
    
    # predictions = model.predict(test_x)
    dict_results[name] = [model.score(train_x, train_y), model.score(test_x, test_y), model.score(train_x, train_y) - model.score(test_x, test_y),
                         train_rmse, test_rmse]

# transform dict_models to dataframe
df_models = pd.DataFrame.from_dict(dict_results, orient='index', columns=['R2_train_data', 'R2_test_data', 'R2_diff', 'RMSE_train_data', 'RMSE_test_data'])
df_models
# Out:
#                                 R2_train_data  \
# LR                                     0.8856
# CART                                   1.0000
# RF                                     1.0000
# XGB                                    0.9807
#
#                                  R2_test_data  \
# LR                                     0.8850
# CART                                   0.9480
# RF                                     0.9673
# XGB                                    0.9669
#
#                                       R2_diff  \
# LR                                     0.0006
# CART                                   0.0520
# RF                                     0.0327
# XGB                                    0.0138
#
#                               RMSE_train_data  \
# LR                                     0.3382
# CART                                   0.0000
# RF                                     0.0058
# XGB                                    0.1391
#
#                                RMSE_test_data
# LR                                     0.3391
# CART                                   0.2281
# RF                                     0.1809
# XGB                                    0.1820

# %% [markdown]
# The **RF** model has the highest R2 score and lowest RMSE on the test set, making it the best-performing model.
# The **XGBoost** model is also performing well. The **CART** model appears to be overfitting as it has a large difference in R2 score between training and testing sets. The **LR** model is performing reasonably well, but not as well as the tree-based models.
#
# In summary, the tree-based models are performing better than the **LR** model, and the **RF** model is the best-performing model overall.

# %% [markdown]
# #### 5.1.3. Feature importance

# %% [markdown]
# Permutation feature importance measures the importance of each feature by shuffling its values and evaluating how much the model performance decreases as a result of the shuffling.

# %%
from sklearn.inspection import permutation_importance

fig, axs = plt.subplots(nrows=len(classifiers), ncols=2, figsize=(10, 5*len(classifiers)))

# Loop through each classifier and calculate permutation importances
for i, (name, classifier) in enumerate(classifiers.items()):
    # Fit the pipeline
    pipeline = Pipeline(steps=[('classifier', classifier)])
    model = pipeline.fit(train_x, train_y)

    # Calculate permutation importances
    result = permutation_importance(model, test_x, test_y, n_repeats=10, random_state=random_state_split, n_jobs=-1)

    # Plot feature importances
    sorted_idx = result.importances_mean.argsort()
    axs[i, 0].barh(train_x.columns[sorted_idx], result.importances_mean[sorted_idx], color='#fe346e')
    axs[i, 0].set_title(f'Permutation Importances ({name})')
    axs[i, 0].set_xlabel('Importance')

    # Create dataframe of feature importances
    df_importance = pd.DataFrame({'Feature': train_x.columns[sorted_idx], 'Importance': result.importances_mean[sorted_idx].round(3)})
    df_top_five = df_importance.sort_values(by='Importance', ascending=False).head(5)
    axs[i, 1].axis('off')
    axs[i, 1].axis('tight')
    axs[i, 1].table(cellText=df_top_five.values, colLabels=df_top_five.columns, loc= 'center')

# Figure numbering
plt.title('Figure 13. Feature Importance', fontsize=13, fontweight='bold',x=-1.25, y=-0.4, font = 'Serif')
    
# Adjust spacing between subplots
plt.subplots_adjust(hspace=0.5)

# Show the plot
plt.show()

# %% [markdown]
# Different models may rank the importance of features differently, but identifying the top important features across all models can give you a better understanding of the overall importance of each feature.
#
# For **LR**, `Online Boarding` and `Customer Type` are the top two features.
#
# For **CART**, `In-flight Wifi Service` is the most important feature, followed by `Customer Type` and `Online Boarding`.
#
# For **RF** and **XGB**, `Customer Type` is the most important feature, followed by `In-flight Wifi Service` and `Online Boarding`.

# %% [markdown]
# #### 5.1.4. Performance metrics

# %%
classifiers = {
    'LR': LogisticRegression(random_state=random_state_split),
    'CART': DecisionTreeClassifier(random_state=random_state_split),
    'RF': RandomForestClassifier(random_state=random_state_split),
    'XGB': XGBClassifier(random_state=random_state_split)
}

results = []

for name, classifier in classifiers.items():
    if name == 'KNN':
        pipeline = Pipeline(steps=[('selector', SelectKBest(chi2, k=3)), ('classifier', classifier)])
    else:
        pipeline = Pipeline(steps=[('classifier', classifier)])

    pipeline.fit(train_x, train_y)

    y_pred = pipeline.predict(test_x)
    accuracy = accuracy_score(test_y, y_pred)
    precision = precision_score(test_y, y_pred)
    recall = recall_score(test_y, y_pred)
    f1 = f1_score(test_y, y_pred)
    cm = confusion_matrix(test_y, y_pred)

    results.append({
        'Algorithm': name,
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1': f1,
        'Confusion Matrix': cm
    })

df_results = pd.DataFrame(results)

# %%
df_results
# Out:
#   Algorithm                                 Accuracy  \
# 0        LR                                   0.8850
# 1      CART                                   0.9480
# 2        RF                                   0.9673
# 3       XGB                                   0.9669
#
#                                  Precision  \
# 0                                   0.9009
# 1                                   0.9544
# 2                                   0.9799
# 3                                   0.9788
#
#                                     Recall  \
# 0                                   0.9018
# 1                                   0.9563
# 2                                   0.9635
# 3                                   0.9640
#
#                                         F1               Confusion Matrix
# 0                                   0.9013  [[7259, 1165], [1153, 10585]]
# 1                                   0.9554    [[7888, 536], [513, 11225]]
# 2                                   0.9716    [[8192, 232], [428, 11310]]
# 3                                   0.9713    [[8179, 245], [423, 11315]]

# %% [markdown]
# The **RF** and **XGB** algorithms performed the best, with the highest accuracy, precision, recall, and F1-score. Confusion matrices show they correctly predicted over 11,000 true positives, but RF had fewer false negatives and XGB had fewer false positives. The **CART** also performed well, but had slightly lower scores than **RF** and **XGB**. The **LR** had the lowest scores overall, but still achieved decent performance.

# %%
end_time = time.time()
run_time = end_time - start_time
print("Total run time: ", run_time, "seconds")
# Out:
# Total run time:  44.535579204559326 seconds

# %% [markdown]
# ## 6. Discussion and Conclusion

# %% [markdown]
# The results of this study suggest that `Customer Type` is a crucial factor contributing to business visitors' satisfaction. Interestingly, this finding is consistent across all models, indicating that airlines should prioritise their efforts towards satisfying this customer segment. For example, for first-timers, airlines can provide more detailed information and assistance throughout the journey, while for returning customers, they can focus on offering personalised services and rewards to enhance their loyalty and satisfaction. Additionally, `In-flight Wifi Service` and `Online Boarding` are also significant factors in determining satisfaction, although their importance rankings vary between models. Therefore, airline companies should consider investing in these amenities to improve the satisfaction of their customers.
#
# **Limitations**
#
# It is worth noting that the use of LabelEncoder to encode categorical variables may have introduced some bias, particularly in cases where no such order exists. Therefore, future studies should consider alternative encoding methods that do not introduce any bias.
#
# Furthermore, it is important to emphasise that the feature importance scores do not necessarily indicate causality in the relationship between the features and the target variable. Rather, they provide information about the relative importance of each feature in the predictive model. Therefore, additional research is needed to further investigate the causal relationships between these factors and customer satisfaction.
#
# **Conclusion**
#
# In conclusion, this study has identified several factors that contribute to business visitors' satisfaction with airline services. The findings suggest airlines should prioritise their efforts towards satisfying their business customers, particularly by considering `Customer Type`. In addition, investing in `In-flight Wifi Service` and `Online Boarding` amenities may also enhance overall customer satisfaction. Further research is needed to validate these findings and explore the differences in satisfaction factors between business and leisure travelers, allowing airline companies to tailor their strategies accordingly.

# %% [markdown]
# ## Bibliography

# %% [markdown]
# Archana, R. and Subha, M.V., 2012. A study on service quality and passenger satisfaction on Indian airlines. International Journal of Multidisciplinary Research, 2(2), pp.50-63.
#
# Branco, P., Torgo, L. and Ribeiro, R.P., 2016. A survey of predictive modeling on imbalanced domains. ACM computing surveys (CSUR), 49(2), pp.1-50.
#
# International Civil Aviation Organization (ICAO). 2019. Aviation Benefits Report[PDF]. Available at: https://www.icao.int/sustainability/Documents/AVIATION-BENEFITS-2019-web.pdf. (Accessed: 13.04.2023)
#
# Li, T., Yi, X., Carmanis, C. and Ravikumar, P., 2017, April. Minimax gaussian classification & clustering. In Artificial Intelligence and Statistics (pp. 1-9). PMLR.
#
# Noviantoro, T. and Huang, J.P., 2022. Investigating airline passenger satisfaction: Data mining method. Research in Transportation Business & Management, 43, p.100726.
#
# Suki, N.M., 2014. Passenger satisfaction with airline service quality in Malaysia: A structural equation modeling approach. Research in transportation business & management, 10, pp.26-32.
